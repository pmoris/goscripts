# %% [markdown]
# # GO enrichment analysis of Ebola virus - human protein-protein interaction network and bat orthologues.
#
# Pieter Moris 2017
# ADReM - UAntwerpen
#
# Continuation of Ben Verhees' work in 2015

# %% [markdown]
# ## Data collection and pre-processing
# The entire pre-processing pipeline was bundled in a bash script in ` data_preprocessing/data_setup.sh`.

# %% [markdown]
# The Ebola virus - human protein-protein interaction network was retrieved from the Host - Pathogen Interaction Database (HPIDB) 2.0 (http://www.agbase.msstate.edu/hpi/main.html, last updated June 28, 2016) by downloading the full dataset and extracting all the interactions involving ebola. The following NCBI taxon id's were used:

# %% [markdown]
# ```128951  Ebola virus - Zaire (1995) count: 3
# 128952  Ebola virus - Mayinga, Zaire, 1976 count: 254
# 186538  Zaire ebolavirus count: 1
# 386032  Reston ebolavirus - Reston (1989) count: 3
# 9606    Homo sapiens count: 261```

# %% [markdown]
# Note that the reston virus was also included for these analyses.

# %% [markdown]
# The total size of the protein-protein interaction network was 261 (155 after omitting identical interactions with difference evidence levels) and involved 147 unique human proteins.

# %% [markdown]
# Next, the one-on-one orthology mapping between the human and *Myotis lucifugus* genomes was retrieved from the genome pair view in OMA browser (http://omabrowser.org/oma/genomePW/). In total, 20,121 pairs were found in the database, although a number of proteins were involved in multiple pair mappings. The total number of unique human proteins for which at least one orthologue was found, was 15,033.

# %% [markdown]
# Finally, the human gene ontology mapping (in .obo format) and gene associations (in .gaf format) were obtained from http://purl.obolibrary.org/obo/go/releases/2016-11-26/ and ftp://ftp.ebi.ac.uk/pub/databases/GO/goa/HUMAN/ respectively.

# %% [markdown]
# It was found that 27 of the ebola-interacting human proteins lacked an orthologue in *Myotis lucifugus*.

# %% [markdown]
# ## Gene ontology enrichment analysis

# %% [markdown]
# ### Are ebola-interacting human genes that lack a bat orthologue enriched?

# %% [markdown]
# An enrichment analysis was carried out to answer the following research question: "Of all the human proteins that interact with ebola virus proteins, is the subset of these that do not have a corresponding bat orthologue enriched for a particular biological process or function?"
#
# In other words, we will compare the entire set of human proteins in the human-ebola protein-protein interaction network, with the subset of human proteins that lack a bat orthologue.

# %% [markdown]
# The GO tool was configured to test from the bottom up, i.e. the most specific GO terms were tested first. Only when these terms were not found to be significant (default threshold 0.05), we propagate upwards through the tree and test the parent GO terms. In addition, any GO term with fewer than three representatives (default setting) will be skipped regardless. Finally, the Benjamini Hochberg multiple testing correction (i.e. the false discovery rate) is applied with a separate significance threshold (default = 0.1).

# %%
# %run ../go-enrichment-tool/go_enrichment_script.py -b ../data/background.txt -s ../data/interest.txt -o ../data/go_data/go.obo -g ../data/go_data/goa_human.gaf -O ../output -m 3 -t 0.1 -T 0.05
# Out:
# Retrieved 27 subset uniprot AC's from /media/pieter/DATA/ebola-go/data/interest.txt
# Retrieved 147 background uniprot AC's from /media/pieter/DATA/ebola-go/data/background.txt
# Retrieved 145 annotated (background filtered) uniprot AC's from /media/pieter/DATA/ebola-go/data/go_data/goa_human.gaf
#
# WARNING! background gene set contained genes not present in the gene association file...
# Removing these genes from the background set...
# WARNING! interest gene set contained genes not present in the gene association file...
 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43565629772525916, 0.43949046644131751, 0.43949046644131751, 0.43949046644131751, 0.43949046644131751, 0.44738149939457672, 0.44 ...
# 0 GO categories out of 508 were significant after FDR multiple testing correction.
#
# GO-term, description and uncorrected and FDR-corrected p-values:
# [['GO:0031490' '0.030177236694315063' '0.9999998263296284'
#   'chromatin DNA binding']
#  ['GO:0070603' '0.036117191754613955' '0.9999999920514706'
#   'SWI/SNF superfamily-type complex']
#  ['GO:0043566' '0.047855002725487414' '0.9999999999832597'
#   'structure-specific DNA binding']
#  ...,
#  ['GO:0046903' '0.7376290092358113' '1.0' 'secretion']
#  ['GO:0036230' '0.8591941120572201' '1.0' 'granulocyte activation']
#  ['GO:0034976' '0.43565629772525916' '1.0'
#   'response to endoplasmic reticulum stress']]

# %% [markdown]
# ### Are human genes that lack a bat orthologoue enriched compared to the entire human annotation set?

# %%
# %run ../go-enrichment-tool/go_enrichment_script.py -b ../data/background.txt -s ../data/interest.txt -o ../data/go_data/go.obo -g ../data/go_data/goa_human.gaf -O ../output -m 0 -t 0.1 -T 0
# Out:
# Retrieved 27 subset uniprot AC's from /media/pieter/DATA/ebola-go/data/interest.txt
# Retrieved 147 background uniprot AC's from /media/pieter/DATA/ebola-go/data/background.txt
# Retrieved 145 annotated (background filtered) uniprot AC's from /media/pieter/DATA/ebola-go/data/go_data/goa_human.gaf
#
# WARNING! background gene set contained genes not present in the gene association file...
# Removing these genes from the background set...
# WARNING! interest gene set contained genes not present in the gene association file...
# Removing these genes from the interest set...
# Retrieved 45914 GO terms from /media/pieter/DATA/ebola-go/data/go_data/go.obo
# Propagating through ontology to find all children and parents for each term...
# Tested 710 GO categories.
# 0 were significant at alpha = 0.0
#
# Tested GO-terms and their p-values:
# {'GO:0007077': 0.53501258333706492, 'GO:0016043': 0.5079728819467868, 'GO:0071840': 0.5079728819467868, 'GO:0008150': 0.38254283924055632, 'GO:0009987': 0.11473072350902329, 'GO:0022402': 0.59349594822832286, 'GO:0044802': 0.50982074032120683, 'GO:0044699': 0.96819060481261232, 'GO:0061024': 0.6316985466627616, 'GO:0044763': 0.93088962882998993, 'GO:0030397': 0.53501258333706492, 'GO:0022411': 0.097326131928623438, 'GO:0006998': 0.53501258333706492, 'GO:1903047': 0.73762900923581132, 'GO:0051081': 0.53501258333706492, 'GO:0005635': 0.61745716075961021, 'GO:0005575': 1.0, 'GO:0044424': 1.0, 'GO:0044464': 1.0, 'GO:0044422': 0.81353524089371687, 'GO:0031967': 0.61745716075961021, 'GO:0044446': 0.81353524089371687, 'GO:0031975': 0.61745716075961021, 'GO:0044428': 0.69168200140915126, 'GO:0017056': 0.43565629772525916, 'GO:0003674': 0.68390804597700494, 'GO:0005198': 0.14226271373471705, 'GO:0008139': 0.3466695137637944, 'GO:0042277': 0.3466695137637944, 'GO:0005488': 0.68390804597700494, 'GO:0033218': 0.3466695137637944, 'GO:0005048': 0.3466695137637944, 'GO:0005654': 0.53803401716879
 0.076963266618442799, 0.076963266618442799, 0.076963266618442799, 0.076963266618442799, 0.076963266618442799, 0.076963266618442799, 0.076963266618442799, 0.076963266618442799, 0.076963266618442799, 0.076963266618442799, 0.079823874882008233, 0.08859349547441496, 0.097326131928623438, 0.097326131928623438, 0.097326131928623438, 0.097326131928623438, 0.098770220455378852, 0.098979905622454609, 0.098979905622454609, 0.098979905622454609, 0.098979905622454609, 0.11473072350902329, 0.12303806214082333, 0.12816924531120394, 0.12868980792965762, 0.130865506539878, 0.130865506539878, 0.13758744089002259, 0.13758744089002259, 0.13758744089002259, 0.13758744089002259, 0.13758744089002259, 0.13758744089002259, 0.13758744089002259, 0.13758744089002259, 0.13758744089002259, 0.13758744089002259, 0.13758744089002259, 0.13758744089002259, 0.14026150697936837, 0.14026150697936837, 0.14026150697936837, 0.14026150697936837, 0.14026150697936837, 0.14226271373471705, 0.14226271373471705, 0.14686924638118709, 0.14686924638118709, 0.14686924638118709, 0.14686924638118709, 0.14686924638118709, 0.14686924638118709, 0.14686924638118709, 0.14725156050968258, 0.14882285492993719, 0.1596090202895564, 0.1596090202895564, 0.16353429596564747, 0.17018995777577955, 0.17018995777577955, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.17241379310344743, 0.172 ...
# 0 GO categories out of 710 were significant after FDR multiple testing correction.
#
# GO-term, description and uncorrected and FDR-corrected p-values:
# [['GO:0007399' '0.02873563218390792' '0.9999999989776632'
#   'nervous system development']
#  ['GO:0031490' '0.030177236694315063' '0.9999999996328084'
#   'chromatin DNA binding']
#  ['GO:0070603' '0.036117191754613955' '0.9999999999951117'
#   'SWI/SNF superfamily-type complex']
#  ...,
#  ['GO:0044267' '0.6094482726646369' '1.0'
#   'cellular protein metabolic process']
#  ['GO:0006996' '0.9081177338723561' '1.0' 'organelle organization']
#  ['GO:0043021' '0.31609195402298434' '1.0'
#   'ribonucleoprotein complex binding']]

# %%
# %run ../go-enrichment-tool/go_enrichment_script.py -s ../data/interest.txt -o ../data/go_data/go.obo -g ../data/go_data/goa_human.gaf -O ../output -m 0 -t 0.1 -T 0
# Out:
# Retrieved 27 subset uniprot AC's from /media/pieter/DATA/ebola-go/data/interest.txt
# No background gene set provided, retrieving all genes from the gene annotation file...
# Retrieved 19363 annotated uniprot AC's from /media/pieter/DATA/ebola-go/data/go_data/goa_human.gaf after filtering on the background set.
#
# WARNING! interest gene set contained genes not present in the gene association file...
# Removing these genes from the interest set...
# Retrieved 45914 GO terms from /media/pieter/DATA/ebola-go/data/go_data/go.obo
# Propagating through ontology to find all children and parents for each term...
# Tested 710 GO categories.
# 0 were significant at alpha = 0.0
#
# Tested GO-terms and their p-values:
# {'GO:0007077': 0.055320289623286112, 'GO:0016043': 6.5641025113313736e-05, 'GO:0071840': 7.1947830641113937e-05, 'GO:0008150': 0.059021186887728817, 'GO:0009987': 0.0010030095945770298, 'GO:0022402': 0.15664963900824319, 'GO:0044802': 0.012513528330479234, 'GO:0044699': 0.73222319498086497, 'GO:0061024': 0.041033170442238719, 'GO:0044763': 0.55317705464125944, 'GO:0030397': 0.06020108393112418, 'GO:0022411': 0.0011484028987346837, 'GO:0006998': 0.092518852588701336, 'GO:1903047': 0.25229792008143026, 'GO:0051081': 0.06020108393112418, 'GO:0005635': 0.17893057547851529, 'GO:0005575': 0.30817340696517936, 'G
 0.0068753639378236666, 0.0071908753428363403, 0.007331851575878132, 0.0073585989132455816, 0.0074740817854891837, 0.0077227654612279069, 0.0077227654612279069, 0.0077227654612279069, 0.0077227654612279069, 0.0077227654612279069, 0.0077227654612279069, 0.0077227654612279069, 0.0077227654612279069, 0.0077470913913542305, 0.0077622913229971726, 0.0077622913229971726, 0.0077622913229971726, 0.0078228128189858741, 0.0084045534454976444, 0.0086566832720756225, 0.0090043137827503835, 0.0090043137827503835, 0.0090043137827503835, 0.0095083570602487715, 0.010199430503001317, 0.010284273080009575, 0.010284273080009575, 0.010284273080009575, 0.010284273080009575, 0.010284273080009575, 0.010548370340966375, 0.01057712714946816, 0.010752589304550827, 0.011562645241339339, 0.011562645241339339, 0.011562645241339339, 0.011562645241339339, 0.011562645241339339, 0.011911177753859336, 0.012487935218496161, 0.012513528330479234, 0.012660182536876813, 0.012839432151164209, 0.012839432151164209, 0.012839432151164209, 0.012839432151164209, 0.012839432151164209, 0.012839432151164209, 0.012983818171401295, 0.013033473112068634, 0.013217613318487875, 0.013408247139774817, 0.013425132914205117, ...
# 30 GO categories out of 710 were significant after FDR multiple testing correction.
#
# GO-term, description and uncorrected and FDR-corrected p-values:
# [['GO:0032991' '1.4495172564995387e-07' '0.00010204081571585366'
#   'macromolecular complex']
#  ['GO:0044427' '3.430448260117733e-07' '0.00024113147716642302'
#   'chromosomal part']
#  ['GO:1901363' '4.937785214058941e-07' '0.00034657253746428474'
#   'heterocyclic compound binding']
#  ...,
#  ['GO:0071824' '6.086608239888865e-09' '4.297136181885541e-06'
#   'protein-DNA complex subunit organization']
#  ['GO:0044815' '6.8362691186771e-10' '4.833241248336506e-07'
#   'DNA packaging complex']
#  ['GO:0032993' '1.07756749451566e-10' '7.650732758435197e-08'
#   'protein-DNA complex']]

# %%
type(output[:,0])
# Out:
# numpy.ndarray

# %%
GOterms[output[0,0]].name
# Out:
# 'macromolecular complex'

# %%
[GOterms[x].name for x in output[:,0]]
# Out:
# ['macromolecular complex',
#  'chromosomal part',
#  'heterocyclic compound binding',
#  'organic cyclic compound binding',
#  'intracellular organelle part',
#  'organelle part',
#  'nucleic acid binding',
#  'chromatin DNA binding',
#  'nuclear part',
#  'nucleosomal DNA binding',
#  'structure-specific DNA binding',
#  'nuclear chromosome part',
#  'nucleosome binding',
#  'small molecule binding',
#  'cellular component organization',
#  'cellular component organization or biogenesis',
#  'RNA polymerase II distal enhancer sequence-specific DNA binding',
#  'nucleotide binding',
#  'nucleoside phosphate binding',
#  'npBAF complex',
#  'nucleoplasm',
#  'macromolecular complex subunit organization',
#  'SWI/SNF superfamily-type complex',
#  'nBAF complex',
#  'enhancer sequence-specific DNA binding',
#  'SWI/SNF complex',
#  'protein heterodimerization activity',
#  'enhancer binding',
#  'translation elongation factor activity',
#  'cellular macromolecular complex assembly',
#  'intracellular part',
#  'BAF-type complex',
#  'nuclear localization sequence binding',
#  'DNA binding',
#  'RNA binding',
#  'cellular macromolecule metabolic process',
#  'binding',
#  'single-organism intracellular transport',
#  'protein binding',
#  'cellular component assembly',
#  'vesicle',
#  'establishment of protein localization to organelle',
#  'cellular process',
#  'protein targeting to membrane',
#  'cellular component disassembly',
#  'carbohydrate derivative binding',
#  'macromolecular complex assembly',
#  'dihydroorotase activity',
#  'aspartate carbamoyltransferase activity',
#  'aspartate binding',
#  'GTP binding',
#  'extracellular exosome',
#  'cellular metabolic process',
#  'extracellular vesicle',
#  'extracellular organelle',
#  'signal sequence binding',
#  'purine ribonucleoside triphosphate binding',
#  'guanyl ribonucleotide binding',
#  'guanyl nucleotide binding',
#  'purine ribonucleoside binding',
#  'extracellular region part',
#  'purine nucleoside binding',
#  'ribonucleoside binding',
#  'nucleoside binding',
#  'purine ribonucleotide binding',
#  'structural molecule activity',
#  'purine nucleotide binding',
#  'ribonucleotide binding',
#  'intracellular protein transport',
#  'single-organism cellular localization',
#  'carbamoyl-phosphate synthase (glutamine-hydrolyzing) activity',
#  'negative regulation of transcription during mitotic cell cycle',
#  'carboxyl- or carbamoyltransferase activity',
#  'negative regulation of transcription from RNA polymerase II promoter during mitotic cell cycle',
#  'covalent chromatin modification',
#  'cellular protein localization',
#  'cellular macromolecule localization',
#  'macromolecule metabolic process',
#  'chromatin binding',
#  'intracellular ribonucleoprotein complex',
#  'ribonucleoprotein complex',
#  'organic substance metabolic process',
#  'protein localization to organelle',
#  'regulation of transcription during mitotic cell cycle',
#  'regulation of glucose mediated signaling pathway',
#  'positive regulation of glucose mediated signaling pathway',
#  'cellular heat acclimation',
#  'positive regulation of nucleotide-binding oligomerization domain containing 2 signaling pathway',
#  'regulation of transcription from RNA polymerase II promoter during mitotic cell cycle',
#  "'de novo' UMP biosynthetic process",
#  'heat acclimation',
#  'neurofilament bundle assembly',
#  'positive regulation of nucleotide-binding oligomerization domain containing signaling pathway',
#  'peripheral nervous system neuron axonogenesis',
#  'intracellular organelle',
#  'inclusion body',
#  'anion binding',
#  'intracellular transport',
#  'establishment of protein localization to membrane',
#  'macromolecular complex binding',
#  'nucleobase-containing compound metabolic process',
#  'steroid hormone receptor binding',
#  'transcriptional repressor complex',
#  'signal recognition particle receptor complex',
#  'terminal button organization',
#  'protein targeting',
#  'modification of morphology or physiology of other organism involved in symbiotic interaction',
#  'translation factor activity, RNA binding',
#  'SRP-dependent cotranslational protein targeting to membrane',
#  'negative regulation of G1/S transition of mitotic cell cycle',
#  'signal recognition particle binding',
#  'neurofibrillary tangle',
#  'negative regulation of cell cycle G1/S phase transition',
#  'metabolic process',
#  'cotranslational protein targeting to membrane',
#  'heterocycle metabolic process',
#  'protein targeting to ER',
#  'protein import into nucleus',
#  'cellular aromatic compound metabolic process',
#  'histone deacetylase binding',
#  'C3HC4-type RING finger domain binding',
#  'intermediate filament bundle assembly',
#  'hydrolase activity, acting on carbon-nitrogen (but not peptide) bonds, in cyclic amides',
#  'modification of morphology or physiology of other organism',
#  "'de novo' pyrimidine nucleobase biosynthetic process",
#  'single-organism nuclear import',
#  'positive regulation of tumor necrosis factor-mediated signaling pathway',
#  'negative regulation of gene expression',
#  'histone H3-K27 trimethylation',
#  'pyrimidine nucleobase biosynthetic process',
#  'membrane-bounded organelle',
#  'regulation of nucleotide-binding oligomerization domain containing 2 signaling pathway',
#  'establishment of protein localization to endoplasmic reticulum',
#  'protein localization to membrane',
#  'protein localization to endoplasmic reticulum',
#  'translation activator activity',
#  'dendritic spine head',
#  'positive regulation of transcription of nuclear large rRNA transcript from RNA polymerase I promoter',
#  'establishment of localization in cell',
#  'organelle',
#  'RNA polymerase I CORE element sequence-specific DNA binding',
#  'RNA polymerase I regulatory region DNA binding',
#  'RNA polymerase I regulatory region sequence-specific DNA binding',
#  'neurofilament',
#  'nucleosome positioning',
#  'organic cyclic compound metabolic process',
#  'nuclear import',
#  'negative regulation of transcription, DNA-templated',
#  'regulation of nucleotide-binding oligomerization domain containing signaling pathway',
#  'histone H3-K27 methylation',
#  'neurofilament cytoskeleton organization',
#  'regulation of transcription of nuclear large rRNA transcript from RNA polymerase I promoter',
#  'Tat protein binding',
#  'cellular nitrogen compound metabolic process',
#  'nuclear hormone receptor binding',
#  'single-organism membrane organization',
#  'negative regulation of nucleic acid-templated transcription',
#  'UMP metabolic process',
#  'carbon-nitrogen ligase activity, with glutamine as amido-N-donor',
#  'UMP biosynthetic process',
#  'pyrimidine ribonucleoside monophosphate metabolic process',
#  'mitotic G1 DNA damage checkpoint',
#  'pyrimidine ribonucleoside monophosphate biosynthetic process',
#  'protein dimerization activity',
#  'regulation of G1/S transition of mitotic cell cycle',
#  'protein localization to nucleus',
#  'negative regulation of RNA biosynthetic process',
#  'focal adhesion',
#  'cell-substrate adherens junction',
#  'G1 DNA damage checkpoint',
#  'UTP biosynthetic process',
#  'cell-substrate junction',
#  'mitotic G1/S transition checkpoint',
#  'telomere capping',
#  'hydrolase activity, acting on carbon-nitrogen (but not peptide) bonds',
#  'protein import',
#  'myelin sheath',
#  'regulation of cell cycle G1/S phase transition',
#  'UTP metabolic process',
#  'nuclear nucleosome',
#  'negative regulation of RNA metabolic process',
#  'regulation of microtubule-based process',
#  'macromolecule modification',
#  'ribonucleoside triphosphate metabolic process',
#  'interspecies interaction between organisms',
#  'hormone receptor binding',
#  'pyrimidine nucleoside monophosphate biosynthetic process',
#  'cellular protein metabolic process',
#  'histone binding',
#  'regulation of mitotic spindle assembly',
#  'DNA polymerase binding',
#  'neural retina development',
#  'pyrimidine nucleoside monophosphate metabolic process',
#  'positive regulation by host of viral transcription',
#  'multi-organism process',
#  'histone H3-K4 trimethylation',
#  'retinoid X receptor binding',
#  'negative regulation of cellular macromolecule biosynthetic process',
#  'protein transport',
#  'nucleic acid metabolic process',
#  'structural constituent of ribosome',
#  'cell part',
#  'poly(U) RNA binding',
#  'cytoplasmic translation',
#  'regulation of spindle assembly',
#  'pyrimidine ribonucleoside triphosphate biosynthetic process',
#  'cellular localization',
#  'nucleoside triphosphate metabolic process',
#  'negative regulation of macromolecule metabolic process',
#  'ribonucleoside monophosphate metabolic process',
#  'myosin V binding',
#  'CHD-type complex',
#  'pyrimidine ribonucleoside triphosphate metabolic process',
#  'NuRD complex',
#  'ribosomal small subunit assembly',
#  'mannose binding',
#  'positive regulation of transcription from RNA polymerase I promoter',
#  'nucleobase biosynthetic process',
#  'cysteine-type endopeptidase activator activity involved in apoptotic process',
#  'cytoskeletal protein binding',
#  'translation regulator activity, nucleic acid binding',
#  'lysine-acetylated histone binding',
#  'neuron part',
#  'negative regulation of mitotic cell cycle phase transition',
#  'regulation of mitotic cell cycle',
#  'nucleoside monophosphate metabolic process',
#  'adherens junction',
#  'ribosomal subunit',
#  'acrosomal membrane',
#  'poly-pyrimidine tract binding',
#  'pyrimidine nucleobase metabolic process',
#  'negative regulation of nucleobase-containing compound metabolic process',
#  'negative regulation of macromolecule biosynthetic process',
#  'peptidase activator activity involved in apoptotic process',
#  'negative regulation of cell cycle phase transition',
#  'nitrogen compound metabolic process',
#  'pyrimidine nucleoside triphosphate biosynthetic process',
#  'positive regulation of pri-miRNA transcription from RNA polymerase II promoter',
#  'dynein complex binding',
#  'protein heterotetramerization',
#  'anchoring junction',
#  'structural constituent of nuclear pore',
#  'transcription factor binding',
#  'decidualization',
#  'intermediate filament organization',
#  'single-organism transport',
#  'regulation of mitotic spindle organization',
#  'NLS-bearing protein import into nucleus',
#  'pyrimidine ribonucleoside biosynthetic process',
#  'establishment of protein localization',
#  'translation',
#  'modulation by host of symbiont transcription',
#  'pyrimidine ribonucleotide biosynthetic process',
#  'modulation by host of viral transcription',
#  'ionotropic glutamate receptor binding',
#  'regulation of spindle organization',
#  'chromatin assembly',
#  'modulation of transcription in other organism involved in symbiotic interaction',
#  'retinoic acid receptor binding',
#  'protein targeting to plasma membrane',
#  'negative regulation of cellular biosynthetic process',
#  'pyrimidine nucleoside triphosphate metabolic process',
#  'RNA polymerase II regulatory region sequence-specific DNA binding',
#  'pyrimidine ribonucleotide metabolic process',
#  'RNA polymerase II regulatory region DNA binding',
#  'negative regulation of metabolic process',
#  'negative regulation of biosynthetic process',
#  'negative regulation of nitrogen compound metabolic process',
#  'peptide biosynthetic process',
#  'thyroid hormone receptor binding',
#  'protein binding involved in protein folding',
#  'regulation of cell cycle process',
#  'peptidyl-lysine trimethylation',
#  'regulation of transcription from RNA polymerase I promoter',
#  'RNA polymerase II repressing transcription factor binding',
#  'regulation of pri-miRNA transcription from RNA polymerase II promoter',
#  'intrinsic apoptotic signaling pathway in response to DNA damage by p53 class mediator',
#  'peptide binding',
#  'hydrolase activity',
#  'organic substance transport',
#  'cytosolic part',
#  'beta-catenin-TCF complex assembly',
#  'single-organism localization',
#  'nuclear transcriptional repressor complex',
#  'pyrimidine nucleotide biosynthetic process',
#  'pyrimidine nucleoside biosynthetic process',
#  'histone H3-K4 methylation',
#  'glutamate receptor binding',
#  'membrane organization',
#  'pyrimidine ribonucleoside metabolic process',
#  'negative regulation of extrinsic apoptotic signaling pathway in absence of ligand',
#  'negative regulation of signal transduction in absence of ligand',
#  'negative regulation of cell cycle process',
#  'cytoskeletal part',
#  'ribonucleoside metabolic process',
#  'positive regulation of cytokine-mediated signaling pathway',
#  'primary metabolic process',
#  'negative regulation of mitotic cell cycle',
#  'positive regulation of response to cytokine stimulus',
#  'transcription regulatory region sequence-specific DNA binding',
#  'nucleocytoplasmic transport',
#  'macromolecule biosynthetic process',
#  'translation regulator activity',
#  'amide binding',
#  'cellular response to epidermal growth factor stimulus',
#  'polymeric cytoskeletal fiber',
#  'nuclear transport',
#  'nucleobase metabolic process',
#  'mitotic DNA damage checkpoint',
#  'peptidase activator activity',
#  'peptidyl-lysine modification',
#  'estrogen receptor binding',
#  'nucleoside metabolic process',
#  'supramolecular fiber',
#  'supramolecular polymer',
#  'embryo implantation',
#  'polysome',
#  'supramolecular complex',
#  'sequence-specific double-stranded DNA binding',
#  'response to epidermal growth factor',
#  'androgen receptor binding',
#  'positive regulation of viral transcription',
#  'intermediate filament cytoskeleton organization',
#  'protein localization',
#  'ribonucleotide metabolic process',
#  'lactation',
#  'nucleoid',
#  'pyrimidine-containing compound biosynthetic process',
#  'zinc ion binding',
#  'mitochondrial nucleoid',
#  'intermediate filament-based process',
#  'synapse part',
#  'cysteine-type endopeptidase regulator activity involved in apoptotic process',
#  'amide biosynthetic process',
#  'regulation of mitotic cell cycle phase transition',
#  'mitotic nuclear envelope disassembly',
#  'protein metabolic process',
#  'molecular_function',
#  'macromolecule localization',
#  'mitotic DNA integrity checkpoint',
#  'cellular response to heat',
#  'ribose phosphate metabolic process',
#  'response to metal ion',
#  'cytosolic small ribosomal subunit',
#  'glycosyl compound metabolic process',
#  'biological_process',
#  'regulation of extrinsic apoptotic signaling pathway in absence of ligand',
#  'pyrimidine nucleotide metabolic process',
#  'membrane disassembly',
#  'nuclear envelope disassembly',
#  'nervous system development',
#  'regulation of cell cycle phase transition',
#  'cellular response to calcium ion',
#  'ligase activity, forming carbon-nitrogen bonds',
#  'pyrimidine nucleoside metabolic process',
#  'double-stranded DNA binding',
#  'negative regulation of cellular metabolic process',
#  'modification by host of symbiont morphology or physiology',
#  'ion binding',
#  'cytoskeleton organization',
#  'regulation of tumor necrosis factor-mediated signaling pathway',
#  'transport',
#  'interaction with symbiont',
#  'negative regulation of transcription from RNA polymerase II promoter',
#  'IRE1-mediated unfolded protein response',
#  'myosin binding',
#  'histone modification',
#  'cytoplasmic part',
#  'repressing transcription factor binding',
#  'intrinsic apoptotic signaling pathway by p53 class mediator',
#  'cellular macromolecule biosynthetic process',
#  'ribonucleoside triphosphate biosynthetic process',
#  'enzyme binding',
#  'catalytic complex',
#  'secretion by tissue',
#  'peptide metabolic process',
#  'cellular biosynthetic process',
#  'protein modification process',
#  'cellular protein modification process',
#  'cellular response to stimulus',
#  'transcription regulatory region DNA binding',
#  'cytosolic large ribosomal subunit',
#  'regulatory region nucleic acid binding',
#  'regulatory region DNA binding',
#  'histone deacetylase complex',
#  'intrinsic apoptotic signaling pathway in response to DNA damage',
#  'nuclear pore',
#  'regulation of viral transcription',
#  'amino acid binding',
#  'establishment of localization',
#  'regulation of gene expression',
#  'histone lysine methylation',
#  'monosaccharide binding',
#  'organic substance biosynthetic process',
#  'p53 binding',
#  'virus receptor activity',
#  'chromatin assembly or disassembly',
#  'body fluid secretion',
#  'nucleoside triphosphate biosynthetic process',
#  'small ribosomal subunit',
#  'regulation of nitrogen compound metabolic process',
#  'biosynthetic process',
#  'chromosome organization',
#  'organonitrogen compound biosynthetic process',
#  'nuclear envelope organization',
#  'peptidyl-amino acid modification',
#  'ribonucleoside monophosphate biosynthetic process',
#  'single-stranded RNA binding',
#  'regulation of RNA metabolic process',
#  'peptidyl-lysine methylation',
#  'transition metal ion binding',
#  'cellular response to stress',
#  'DNA damage checkpoint',
#  'pyrimidine-containing compound metabolic process',
#  'nucleotide metabolic process',
#  'nucleoside monophosphate biosynthetic process',
#  'nucleoside phosphate metabolic process',
#  'sarcolemma',
#  'mitotic cell cycle checkpoint',
#  'female pregnancy',
#  'histone methylation',
#  'negative regulation of biological process',
#  'vesicle-mediated transport to the plasma membrane',
#  'telomere maintenance',
#  'protein heterooligomerization',
#  'response to inorganic substance',
#  'DNA integrity checkpoint',
#  'telomere organization',
#  'positive regulation of viral life cycle',
#  'response to heat',
#  'establishment of protein localization to plasma membrane',
#  'localization',
#  'cellular nitrogen compound biosynthetic process',
#  'nuclear matrix',
#  'melanosome',
#  'ATP binding',
#  'negative regulation of extrinsic apoptotic signaling pathway',
#  'pigment granule',
#  'nucleobase-containing small molecule metabolic process',
#  'multi-multicellular organism process',
#  'perikaryon',
#  'ribonucleoprotein complex binding',
#  'core promoter sequence-specific DNA binding',
#  'positive regulation of viral process',
#  'adenyl ribonucleotide binding',
#  'ribonucleoside biosynthetic process',
#  'endoplasmic reticulum unfolded protein response',
#  'sequence-specific DNA binding',
#  'regulation of cell cycle',
#  'response to calcium ion',
#  'RNA polymerase II transcription factor binding',
#  'protein tetramerization',
#  'adenyl nucleotide binding',
#  'cellular amide metabolic process',
#  'nucleoside biosynthetic process',
#  'regulation of macromolecule biosynthetic process',
#  'negative regulation of cell cycle',
#  'axonogenesis',
#  'large ribosomal subunit',
#  'regulation of nucleobase-containing compound metabolic process',
#  'unfolded protein binding',
#  'multi-organism reproductive process',
#  'glycosyl compound biosynthetic process',
#  'centriole',
#  'glycosaminoglycan binding',
#  'intracellular non-membrane-bounded organelle',
#  'regulation of microtubule cytoskeleton organization',
#  'regulation of organelle organization',
#  'regulation of cellular component organization',
#  'regulation of organelle assembly',
#  'non-membrane-bounded organelle',
#  'regulation of cellular component biogenesis',
#  'transferase activity, transferring one-carbon groups',
#  'sulfur compound binding',
#  'microtubule organizing center part',
#  'biological regulation',
#  'regulation of biological process',
#  'nucleoplasm part',
#  'regulation of cytoskeleton organization',
#  'cellular response to organic substance',
#  'ubiquitin protein ligase binding',
#  'response to chemical',
#  'response to organic substance',
#  'ubiquitin-like protein ligase binding',
#  'positive regulation of transcription from RNA polymerase II promoter',
#  'regulation of cellular process',
#  'positive regulation of cell communication',
#  'regulation of mitotic nuclear division',
#  'positive regulation of cellular process',
#  'positive regulation of signal transduction',
#  'core promoter binding',
#  'methylation',
#  'regulation of signaling',
#  'regulation of cell communication',
#  'cellular response to growth factor stimulus',
#  'regulation of signal transduction',
#  'cellular response to endogenous stimulus',
#  'regulation of response to cytokine stimulus',
#  'regulation of response to stimulus',
#  'regulation of viral life cycle',
#  'regulation of symbiosis, encompassing mutualism through parasitism',
#  'regulation of multi-organism process',
#  'regulation of viral process',
#  'regulation of cytokine-mediated signaling pathway',
#  'regulation of biological quality',
#  'response to endogenous stimulus',
#  'regulation of protein stability',
#  'carboxylic acid binding',
#  'neuronal cell body',
#  'positive regulation of multi-organism process',
#  'protein stabilization',
#  'extracellular space',
#  'cell junction',
#  'response to growth factor',
#  'cellular response to chemical stimulus',
#  'system development',
#  'regulation of nuclear division',
#  'anatomical structure homeostasis',
#  'homeostatic process',
#  'receptor activity',
#  'catalytic activity',
#  'nucleobase-containing compound biosynthetic process',
#  'mitotic cell cycle process',
#  'heterocycle biosynthetic process',
#  'aromatic compound biosynthetic process',
#  'anatomical structure morphogenesis',
#  'cellular component morphogenesis',
#  'organophosphate biosynthetic process',
#  'single-organism biosynthetic process',
#  'single-organism cellular process',
#  'single-organism process',
#  'cell cycle process',
#  'signal transduction',
#  'apoptotic signaling pathway',
#  'intracellular signal transduction',
#  'nucleotide biosynthetic process',
#  'intrinsic apoptotic signaling pathway',
#  'signal transduction by p53 class mediator',
#  'carbohydrate derivative biosynthetic process',
#  'microtubule cytoskeleton',
#  'cytoskeleton',
#  'ribose phosphate biosynthetic process',
#  'membrane protein complex',
#  'membrane part',
#  'endoplasmic reticulum part',
#  'single-organism developmental process',
#  'response to endoplasmic reticulum stress',
#  'cellular developmental process',
#  'nuclear envelope',
#  'cellular_component',
#  'organelle envelope',
#  'envelope',
#  'positive regulation of biological process',
#  'macromolecule methylation',
#  'DNA metabolic process',
#  'molecular transducer activity',
#  'protein alkylation',
#  'protein oligomerization',
#  'cell part morphogenesis',
#  'transferase activity',
#  'cell projection morphogenesis',
#  'single-organism metabolic process',
#  'small molecule metabolic process',
#  'neuron projection morphogenesis',
#  'cell projection organization',
#  'heparin binding',
#  'ribonucleoprotein complex assembly',
#  'protein complex binding',
#  'intermediate filament',
#  'molecular function regulator',
#  'organic cyclic compound biosynthetic process',
#  'enzyme activator activity',
#  'enzyme regulator activity',
#  'peptidase regulator activity',
#  'single-organism organelle organization',
#  'nucleoside phosphate biosynthetic process',
#  'protein complex',
#  'cellular response to DNA damage stimulus',
#  'cell cycle checkpoint',
#  'organelle organization',
#  'ribonucleoprotein complex subunit organization',
#  'positive regulation of signaling',
#  'membrane-enclosed lumen',
#  'positive regulation of nucleic acid-templated transcription',
#  'cellular response to inorganic substance',
#  'cellular response to metal ion',
#  'anatomical structure development',
#  'tissue development',
#  'leukocyte activation involved in immune response',
#  'secretion',
#  'mitochondrial part',
#  'neutrophil degranulation',
#  'positive regulation of intracellular signal transduction',
#  'positive regulation of immune system process',
#  'regulation of intracellular signal transduction',
#  'regulation of immune response',
#  'mitochondrial inner membrane',
#  'organelle inner membrane',
#  'mitochondrial membrane',
#  'regulation of immune system process',
#  'regulation of response to stress',
#  'nucleolus',
#  'regulation of defense response',
#  'regulation of innate immune response',
#  'negative regulation of apoptotic process',
#  'negative regulation of apoptotic signaling pathway',
#  'positive regulation of homeostatic process',
#  'regulation of homeostatic process',
#  'negative regulation of cell death',
#  'negative regulation of programmed cell death',
#  'negative regulation of cell communication',
#  'developmental process involved in reproduction',
#  'membrane',
#  'cell activation',
#  'immune system process',
#  'intracellular vesicle',
#  'cytoplasmic vesicle',
#  'regulation of body fluid levels',
#  'secretory granule membrane',
#  'whole membrane',
#  'vesicle membrane',
#  'organelle membrane',
#  'bounding membrane of organelle',
#  'cytoplasmic vesicle membrane',
#  'sperm part',
#  'single organism reproductive process',
#  'regulated exocytosis',
#  'receptor binding',
#  'protein localization to cell periphery',
#  'leukocyte degranulation',
#  'granulocyte activation',
#  'plasma membrane',
#  'myeloid leukocyte activation',
#  'myeloid cell activation involved in immune response',
#  'single-multicellular organism process',
#  'neutrophil activation involved in immune response',
#  'secretion by cell',
#  'vesicle-mediated transport',
#  'exocytosis',
#  'immune effector process',
#  'cell activation involved in immune response',
#  'leukocyte activation',
#  'cell projection part',
#  'neutrophil activation',
#  'negative regulation of signaling',
#  'reproductive process',
#  'negative regulation of response to stimulus',
#  'regulation of RNA biosynthetic process',
#  'regulation of transcription, DNA-templated',
#  'regulation of cellular macromolecule biosynthetic process',
#  'response to abiotic stimulus',
#  'response to stimulus',
#  'metal ion binding',
#  'cytoplasmic vesicle part',
#  'organelle lumen',
#  'intracellular organelle lumen',
#  'developmental process',
#  'ficolin-1-rich granule lumen',
#  'regulation of transcription from RNA polymerase II promoter',
#  'protein domain specific binding',
#  'regulation of biosynthetic process',
#  'cation binding',
#  'positive regulation of response to stimulus',
#  'positive regulation of RNA biosynthetic process',
#  'positive regulation of macromolecule metabolic process',
#  'positive regulation of metabolic process',
#  'positive regulation of nitrogen compound metabolic process',
#  'positive regulation of nucleobase-containing compound metabolic process',
#  'positive regulation of cellular metabolic process',
#  'positive regulation of RNA metabolic process',
#  'positive regulation of macromolecule biosynthetic process',
#  'positive regulation of biosynthetic process',
#  'positive regulation of cellular biosynthetic process',
#  'positive regulation of transcription, DNA-templated',
#  'positive regulation of gene expression',
#  'protein methylation',
#  'carbohydrate binding',
#  'regulation of cellular biosynthetic process',
#  'organophosphate metabolic process',
#  'multicellular organismal process',
#  'cell body',
#  'organonitrogen compound metabolic process',
#  'negative regulation of signal transduction',
#  'organic acid binding',
#  'negative regulation of cellular process',
#  'regulation of programmed cell death',
#  'regulation of apoptotic process',
#  'protein complex subunit organization',
#  'regulation of nucleic acid-templated transcription',
#  'regulation of apoptotic signaling pathway',
#  'regulation of cell death',
#  'protein complex assembly',
#  'ribonucleotide biosynthetic process',
#  'carbohydrate derivative metabolic process',
#  'regulation of metabolic process',
#  'regulation of primary metabolic process',
#  'regulation of cellular metabolic process',
#  'response to stress',
#  'regulation of macromolecule metabolic process',
#  'phosphorus metabolic process',
#  'regulation of extrinsic apoptotic signaling pathway',
#  'phosphate-containing compound metabolic process',
#  'ligase activity',
#  'response to temperature stimulus',
#  'nucleosome',
#  'nucleosome organization',
#  'chromatin organization',
#  'protein-DNA complex subunit organization',
#  'DNA packaging complex',
#  'protein-DNA complex']
